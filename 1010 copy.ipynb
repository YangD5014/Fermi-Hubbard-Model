# %%
from qiskit_nature.second_q.hamiltonians import FermiHubbardModel
from qiskit_nature.second_q.hamiltonians.lattices import LineLattice,BoundaryCondition
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit.circuit import QuantumCircuit
from qiskit.quantum_info import Statevector
import numpy as np
import scipy
from FermiHubbard_AVQDS import  FH_AVQDS

# %%
num_nodes = 4
boundary_condition = BoundaryCondition.PERIODIC
line_lattice = LineLattice(num_nodes=num_nodes, boundary_condition=boundary_condition)

#U is on site interaction
#J is hopping interaction
J = 1.0
U = 0.1J
fermi_hubbard_model = FermiHubbardModel(
    line_lattice.uniform_parameters(
        uniform_interaction=-1J,
        uniform_onsite_potential=0.0,
    ),
    onsite_interaction=U,
)
Initial_circuit = QuantumCircuit(8)
Initial_circuit.x(range(0,4))

# %%
avqds = FH_AVQDS(EndTime=10.0,N_site=4,U=0.1,J=1.0,Boundary=BoundaryCondition.OPEN,Initial_circuit=Initial_circuit,TimeStep=0.01,max_add=10,max_theta=0.3,dt_max=0.05,Threshold=0.01)
# Out:
# logger init done!
# 正在初始化算算符池...
# Fermi Hubbard HamiltonianPool Init done!N-site=8|length=24

# %%
avqds.MLVP_run()
# Out:
# -----------------第1/个时间步长,当前时间是0.0-------------------
# 目前时间是0.01
# exact_energy=0.19999999999999996
# 本时间步长内的第1次迭代
# 当前的算符是['IIIIIYZY']|当前的参数是[0.]
# Iter=1|operator=['IIIIIYZY']｜Distance=3.9999999999999964
# 当前的算符是['IIIIIXZX']|当前的参数是[0.]
# Iter=1|operator=['IIIIIXZX']｜Distance=3.9999999999999964
# 当前的算符是['IIIYZYII']|当前的参数是[0.]
# Iter=1|operator=['IIIYZYII']｜Distance=2.0000019999986645
# 当前的算符是['IIIXZXII']|当前的参数是[0.]
# Iter=1|operator=['IIIXZXII']｜Distance=2.0000019999986645
# 当前的算符是['IYZYIIII']|当前的参数是[0.]
# Iter=1|operator=['IYZYIIII']｜Distance=3.9999999999999964
# 当前的算符是['IXZXIIII']|当前的参数是[0.]
# Iter=1|operator=['IXZXIIII']｜Distance=3.9999999999999964
# 当前的算符是['IIIIYZYI']|当前的参数是[0.]
# Iter=1|operator=['IIIIYZYI']｜Distance=3.9999999999999964
# 当前的算符是['IIIIXZXI']|当前的参数是[0.]
# Iter=1|operator=['IIIIXZXI']｜Distance=3.9999999999999964
# 当前的算符是['IIYZYIII']|当前的参数是[0.]
# Iter=1|operator=['IIYZYIII']｜Distance=2.0000019999986645
# 当前的算符是['IIXZXIII']|当前的参数是[0.]
# ...

# %%
Initial_circuit.draw('mpl')

# %%
One_site_occupation = QuantumCircuit(8)
One_site_occupation.x(0)
One_site_occupation_state = Statevector(One_site_occupation)
One_site_occupation_state.data
# Out:
# array([0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
# ...
